# 5975  /usr/local/data_citrus/melanose/c_melanose (53...    melanose
# 5976  /usr/local/data_citrus/healthy/c_healthy (5229...     healthy
# 5977  /usr/local/data_citrus/greening/c_greening (29...    greening
# 5978  /usr/local/data_citrus/greening/c_greening (29...    greening
#
# [5979 rows x 2 columns]

# %% [markdown]
# ## Data Visualization

# %%
sns.countplot(x = dataframe["Label"])
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'healthy'),
#   Text(1, 0, 'greening'),
#   Text(2, 0, 'canker'),
#   Text(3, 0, 'melanose'),
#   Text(4, 0, 'black_spot')])

# %% [markdown]
# ## Split Dataset

# %%
batch_size = 64
target_size = (224,224)
validation_split = 0.2
train_gen = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    validation_split = validation_split,
    subset="training",
    seed = 200,
    image_size = target_size,
    batch_size = batch_size
)
valid_gen = tf.keras.preprocessing.image_dataset_from_directory(
    train_data_dir,
    validation_split = validation_split,
    subset="validation",
    seed = 100,
    image_size = target_size,
    batch_size = batch_size
)
# Out:
# Found 5979 files belonging to 5 classes.
# Using 4784 files for training.
# Found 5979 files belonging to 5 classes.
# Using 1195 files for validation.

# %%
class_names = train_gen.class_names
class_names
# Out:
# ['black_spot', 'canker', 'greening', 'healthy', 'melanose']

# %%
plt.figure(figsize=(15,20))
for images, labels in train_gen.take(1):
  for i in range(5):
    ax = plt.subplot(5, 5, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# ## Modelling Network

# %%
base_model = tf.keras.applications.MobileNetV3Small(input_shape=(224,224,3),
                                                    include_top=False, weights='imagenet')
base_model.trainable = False
citrus = keras.models.Sequential()
citrus.add(base_model)
citrus.add(keras.layers.Flatten())
citrus.add(keras.layers.Dropout(0.8))
citrus.add(keras.layers.Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))  # Added dens e layer with L2 regularization
citrus.add(keras.layers.Dense(5, activation = tf.nn.softmax))
citrus.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  MobilenetV3small (Function  (None, 7, 7, 576)         939120
#  al)
#
#  flatten (Flatten)           (None, 28224)             0
#
#  dropout (Dropout)           (None, 28224)             0
#
#  dense (Dense)               (None, 64)                1806400
#
#  dense_1 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 2745845 (10.47 MB)
# Trainable params: 1806725 (6.89 MB)
# Non-trainable params: 939120 (3.58 MB)
# _________________________________________________________________

# %%
# !pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-3.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyparsing>=3.0.9 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.2)
# Installing collected packages: pydot
# Successfully installed pydot-3.0.0

# %%
tf.keras.utils.plot_model(citrus, to_file = 'model.png', show_shapes=True,
                          show_layer_names=True, show_dtype=True, dpi=600)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
checkpoint = ModelCheckpoint("citrus_mbv3.h5", save_best_onnly="True")

# %%
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

# %% [markdown]
# ## Training Phase

# %%
citrus.compile(optimizer ='SGD',loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist=citrus.fit_generator(train_gen, epochs=50, validation_data=valid_gen, callbacks=[checkpoint,early_stopping])
# Out:
# Epoch 1/50
# 75/75 [==============================] - 18s 196ms/step - loss: 2.1986 - accuracy: 0.8232 - val_loss: 1.4182 - val_accuracy: 0.9456
# Epoch 2/50
# 75/75 [==============================] - 14s 181ms/step - loss: 1.4936 - accuracy: 0.9168 - val_loss: 1.3579 - val_accuracy: 0.9498
# Epoch 3/50
# 75/75 [==============================] - 14s 180ms/step - loss: 1.4072 - accuracy: 0.9331 - val_loss: 1.3186 - val_accuracy: 0.9523
# Epoch 4/50
# 75/75 [==============================] - 13s 175ms/step - loss: 1.3565 - accuracy: 0.9406 - val_loss: 1.2592 - val_accuracy: 0.9724
# Epoch 5/50
# 75/75 [==============================] - 13s 169ms/step - loss: 1.3077 - accuracy: 0.9505 - val_loss: 1.2244 - val_accuracy: 0.9699
# Epoch 6/50
# 75/75 [==============================] - 13s 177ms/step - loss: 1.2646 - accuracy: 0.9536 - val_loss: 1.1975 - val_accuracy: 0.9690
# Epoch 7/50
# 75/75 [==============================] - 13s 179ms/step - loss: 1.2168 - accuracy: 0.9544 - val_loss: 1.1502 - val_accuracy: 0.9741
# Epoch 8/50
# 75/75 [==============================] - 13s 178ms/step - loss: 1.1844 - accuracy: 0.9584 - val_loss: 1.1164 - val_accuracy: 0.9791
# Epoch 9/50
# 75/75 [==============================] - 14s 180ms/step - loss: 1.1524 - accuracy: 0.9592 - val_loss: 1.0854 - val_accuracy: 0.9732
# Epoch 10/50
# 75/75 [==============================] - 13s 174ms/step - loss: 1.1196 - accuracy: 0.9617 - val_loss: 1.0546 - val_accuracy: 0.9782
# Epoch 11/50
# 75/75 [==============================] - 13s 174ms/step - loss: 1.0798 - accuracy: 0.9651 - val_loss: 1.0196 - val_accuracy: 0.9841
# Epoch 12/50
# 75/75 [==============================] - 13s 171ms/step - loss: 1.0542 - accuracy: 0.9640 - val_loss: 0.9956 - val_accuracy: 0.9824
# Epoch 13/50
# 75/75 [==============================] - 13s 173ms/step - loss: 1.0250 - accuracy: 0.9626 - val_loss: 0.9714 - val_accuracy: 0.9757
# Epoch 14/50
# 75/75 [==============================] - 13s 173ms/step - loss: 0.9971 - accuracy: 0.9657 - val_loss: 0.9437 - val_accuracy: 0.9766
# Epoch 15/50
# 75/75 [==============================] - 13s 176ms/step - loss: 0.9670 - accuracy: 0.9628 - val_loss: 0.9152 - val_accuracy: 0.9766
# Epoch 16/50
# 75/75 [==============================] - 13s 178ms/step - loss: 0.9359 - accuracy: 0.9689 - val_loss: 0.8899 - val_accuracy: 0.9791
# Epoch 17/50
# 75/75 [==============================] - 13s 173ms/step - loss: 0.9117 - accuracy: 0.9655 - val_loss: 0.8603 - val_accuracy: 0.9824
# Epoch 18/50
# 75/75 [==============================] - 13s 175ms/step - loss: 0.8834 - accuracy: 0.9720 - val_loss: 0.8332 - val_accuracy: 0.9874
# Epoch 19/50
# 75/75 [==============================] - 13s 176ms/step - loss: 0.8652 - accuracy: 0.9666 - val_loss: 0.8115 - val_accuracy: 0.9866
# Epoch 20/50
# 75/75 [==============================] - 13s 171ms/step - loss: 0.8365 - accuracy: 0.9718 - val_loss: 0.7913 - val_accuracy: 0.9841
# Epoch 21/50
# 75/75 [==============================] - 13s 173ms/step - loss: 0.8170 - accuracy: 0.9699 - val_loss: 0.7662 - val_accuracy: 0.9874
# Epoch 22/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.7965 - accuracy: 0.9699 - val_loss: 0.7498 - val_accuracy: 0.9833
# Epoch 23/50
# 75/75 [==============================] - 13s 173ms/step - loss: 0.7692 - accuracy: 0.9743 - val_loss: 0.7289 - val_accuracy: 0.9833
# Epoch 24/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.7514 - accuracy: 0.9735 - val_loss: 0.7124 - val_accuracy: 0.9858
# Epoch 25/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.7370 - accuracy: 0.9693 - val_loss: 0.6925 - val_accuracy: 0.9841
# Epoch 26/50
# 75/75 [==============================] - 13s 172ms/step - loss: 0.7126 - accuracy: 0.9718 - val_loss: 0.6695 - val_accuracy: 0.9891
# Epoch 27/50
# 75/75 [==============================] - 13s 175ms/step - loss: 0.6878 - accuracy: 0.9764 - val_loss: 0.6464 - val_accuracy: 0.9916
# Epoch 28/50
# 75/75 [==============================] - 13s 176ms/step - loss: 0.6835 - accuracy: 0.9695 - val_loss: 0.6318 - val_accuracy: 0.9891
# Epoch 29/50
# 75/75 [==============================] - 13s 177ms/step - loss: 0.6571 - accuracy: 0.9758 - val_loss: 0.6140 - val_accuracy: 0.9908
# Epoch 30/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.6350 - accuracy: 0.9764 - val_loss: 0.5983 - val_accuracy: 0.9908
# Epoch 31/50
# 75/75 [==============================] - 13s 175ms/step - loss: 0.6191 - accuracy: 0.9751 - val_loss: 0.5795 - val_accuracy: 0.9908
# Epoch 32/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.6081 - accuracy: 0.9741 - val_loss: 0.5711 - val_accuracy: 0.9874
# Epoch 33/50
# 75/75 [==============================] - 13s 176ms/step - loss: 0.5897 - accuracy: 0.9766 - val_loss: 0.5532 - val_accuracy: 0.9900
# Epoch 34/50
# 75/75 [==============================] - 13s 177ms/step - loss: 0.5868 - accuracy: 0.9720 - val_loss: 0.5391 - val_accuracy: 0.9908
# Epoch 35/50
# 75/75 [==============================] - 13s 177ms/step - loss: 0.5636 - accuracy: 0.9762 - val_loss: 0.5248 - val_accuracy: 0.9925
# Epoch 36/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.5501 - accuracy: 0.9774 - val_loss: 0.5104 - val_accuracy: 0.9916
# Epoch 37/50
# 75/75 [==============================] - 13s 177ms/step - loss: 0.5341 - accuracy: 0.9772 - val_loss: 0.4974 - val_accuracy: 0.9916
# Epoch 38/50
# 75/75 [==============================] - 13s 175ms/step - loss: 0.5246 - accuracy: 0.9760 - val_loss: 0.4837 - val_accuracy: 0.9916
# Epoch 39/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.5004 - accuracy: 0.9795 - val_loss: 0.4790 - val_accuracy: 0.9874
# Epoch 40/50
# 75/75 [==============================] - 13s 175ms/step - loss: 0.4987 - accuracy: 0.9774 - val_loss: 0.4666 - val_accuracy: 0.9883
# Epoch 41/50
# 75/75 [==============================] - 13s 176ms/step - loss: 0.4804 - accuracy: 0.9799 - val_loss: 0.4510 - val_accuracy: 0.9925
# Epoch 42/50
# 75/75 [==============================] - 14s 181ms/step - loss: 0.4732 - accuracy: 0.9789 - val_loss: 0.4477 - val_accuracy: 0.9858
# Epoch 43/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.4594 - accuracy: 0.9810 - val_loss: 0.4311 - val_accuracy: 0.9883
# Epoch 44/50
# 75/75 [==============================] - 13s 177ms/step - loss: 0.4556 - accuracy: 0.9755 - val_loss: 0.4197 - val_accuracy: 0.9891
# Epoch 45/50
# 75/75 [==============================] - 13s 176ms/step - loss: 0.4456 - accuracy: 0.9785 - val_loss: 0.4074 - val_accuracy: 0.9916
# Epoch 46/50
# 75/75 [==============================] - 13s 174ms/step - loss: 0.4272 - accuracy: 0.9795 - val_loss: 0.3962 - val_accuracy: 0.9925
# Epoch 47/50
# 75/75 [==============================] - 13s 176ms/step - loss: 0.4171 - accuracy: 0.9806 - val_loss: 0.3836 - val_accuracy: 0.9950
# Epoch 48/50
# 75/75 [==============================] - 13s 177ms/step - loss: 0.4099 - accuracy: 0.9776 - val_loss: 0.3810 - val_accuracy: 0.9933
# Epoch 49/50
# 75/75 [==============================] - 13s 177ms/step - loss: 0.3997 - accuracy: 0.9791 - val_loss: 0.3653 - val_accuracy: 0.9916
# Epoch 50/50
# 75/75 [==============================] - 13s 179ms/step - loss: 0.3869 - accuracy: 0.9812 - val_loss: 0.3594 - val_accuracy: 0.9916

# %%
hist_=pd.DataFrame(hist.history)
hist_
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   2.198552  0.823161  1.418165      0.945607
# 1   1.493623  0.916806  1.357934      0.949791
# 2   1.407214  0.933110  1.318593      0.952301
# 3   1.356517  0.940635  1.259174      0.972385
# 4   1.307706  0.950460  1.224415      0.969875
# 5   1.264613  0.953595  1.197547      0.969038
# 6   1.216846  0.954431  1.150198      0.974059
# 7   1.184449  0.958403  1.116440      0.979079
# 8   1.152437  0.959239  1.085397      0.973222
# 9   1.119647  0.961747  1.054584      0.978243
# 10  1.079800  0.965092  1.019642      0.984100
# 11  1.054230  0.964047  0.995620      0.982427
# 12  1.024975  0.962584  0.971422      0.975732
# 13  0.997149  0.965719  0.943706      0.976569
# 14  0.966972  0.962793  0.915229      0.976569
# 15  0.935883  0.968854  0.889867      0.979079
# 16  0.911680  0.965510  0.860339      0.982427
# 17  0.883360  0.971990  0.833209      0.987448
# 18  0.865187  0.966555  0.811497      0.986611
# 19  0.836454  0.971781  0.791260      0.984100
# 20  0.817034  0.969900  0.766203      0.987448
# 21  0.796472  0.969900  0.749834      0.983264
# 22  0.769219  0.974289  0.728942      0.983264
# 23  0.751392  0.973453  0.712431      0.985774
# 24  0.737036  0.969273  0.692519      0.984100
# 25  0.712582  0.971781  0.669506      0.989121
# 26  0.687770  0.976380  0.646363      0.991632
# 27  0.683470  0.969482  0.631809      0.989121
# 28  0.657111  0.975753  0.613987      0.990795
# 29  0.634988  0.976380  0.598277      0.990795
# 30  0.619086  0.975125  0.579523      0.990795
# 31  0.608121  0.974080  0.571138      0.987448
# 32  0.589661  0.976589  0.553222      0.989958
# 33  0.586759  0.971990  0.539053      0.990795
# 34  0.563552  0.976171  0.524762      0.992469
# 35  0.550150  0.977425  0.510399      0.991632
# 36  0.534119  0.977216  0.497405      0.991632
# 37  0.524616  0.975962  0.483711      0.991632
# 38  0.500397  0.979515  0.479015      0.987448
# 39  0.498742  0.977425  0.466567      0.988285
# 40  0.480384  0.979933  0.450959      0.992469
# 41  0.473188  0.978888  0.447703      0.985774
# 42  0.459352  0.980978  0.431096      0.988285
# 43  0.455639  0.975543  0.419732      0.989121
# 44  0.445638  0.978470  0.407373      0.991632
# 45  0.427163  0.979515  0.396194      0.992469
# 46  0.417138  0.980560  0.383565      0.994979
# 47  0.409858  0.977634  0.381001      0.993305
# 48  0.399734  0.979097  0.365269      0.991632
# 49  0.386889  0.981187  0.359415      0.991632

# %%
import os
import shutil

def get_model_size(model):
    model.save('temp_model')
    size = sum(os.path.getsize(os.path.join('temp_model', f)) for f in os.listdir('temp_model') if os.path.isfile(os.path.join('temp_model', f)))
    size_mb = size / (1024 * 1024)  # Đổi từ byte sang MB
    shutil.rmtree('temp_model')  # Xóa thư mục tạm thời sau khi tính toán
    return size_mb

model_size_mb = get_model_size(citrus)
print(f'Model size: {model_size_mb:.2f} MB')
# Out:
# Model size: 3.06 MB

# %%
import time
import numpy as np

def get_inference_time(model, input_shape=(224, 224, 3)):
    input_data = np.random.random([1] + list(input_shape)).astype(np.float32)
    start_time = time.time()
    _ = model.predict(input_data)
    end_time = time.time()
    inference_time_ms = (end_time - start_time) * 1000  # Đổi từ giây sang mili giây
    return inference_time_ms

inference_time_ms = get_inference_time(citrus)
print(f'Speed of single image recognition: {inference_time_ms:.2f} ms')
# Out:
# 1/1 [==============================] - 1s 975ms/step
# Speed of single image recognition: 1037.41 ms

# %% [markdown]
# ## Accuracy

# %%
score, acc = citrus.evaluate(train_gen)
print("Train Loss =", score)
print("Train Accuracy =", acc)
# Out:
# 75/75 [==============================] - 10s 130ms/step - loss: 0.3518 - accuracy: 0.9937
# Train Loss = 0.35178694128990173
# Train Accuracy = 0.9937291145324707

# %%
score_v, acc_v = citrus.evaluate(valid_gen)
print("Test Loss =", score_v)
print("Test Accuracy =", acc_v)
# Out:
# 19/19 [==============================] - 3s 130ms/step - loss: 0.3594 - accuracy: 0.9916
# Test Loss = 0.35941532254219055
# Test Accuracy = 0.991631805896759

# %%
plt.figure(figsize = (15,5))
plt.subplot(1,2,1)
plt.plot(hist_['loss'], label="Train Loss")
plt.plot(hist_['val_loss'], label="Validation Loss")
plt.title("Train Loss & Validation Loss", fontsize=20)
plt.legend()
plt.subplot(1,2,2)
plt.plot(hist_['accuracy'], label="Train Accuracy")
plt.plot(hist_['val_accuracy'], label="Validation Accuracy")
plt.title("Train Accuracy & Validation Accuracy", fontsize=20)
plt.legend()

# %%
## Precision, Recall, and Confusion Matrix
# Evaluate the model and get predictions
y_true = []
y_pred = []

for images, labels in valid_gen:
    predictions = citrus.predict(images)
    predicted_labels = np.argmax(predictions, axis=1)
    y_true.extend(labels.numpy())
    y_pred.extend(predicted_labels)

# Convert lists to arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Calculate Precision and Recall
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()

precision.update_state(y_true, y_pred)
recall.update_state(y_true, y_pred)

precision_score = precision.result().numpy()
recall_score = recall.result().numpy()

print(f"Precision: {precision_score}")
print(f"Recall: {recall_score}")

# Plotting the confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_df = pd.DataFrame(cm, index=[i for i in range(len(cm))], columns=[i for i in range(len(cm))])

plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 80ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 70ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 36ms/step
# Precision: 0.9958071112632751
# Recall: 0.9989484548568726

# %%
## F1 Score
from sklearn.metrics import f1_score

# Calculate F1 Score
f1 = f1_score(y_true, y_pred, average='weighted')
print(f"F1 Score: {f1}")

# Plotting Precision, Recall, and F1 Score
precision_score = precision.result().numpy()
recall_score = recall.result().numpy()

metrics = ['Precision', 'Recall', 'F1 Score']
scores = [precision_score, recall_score, f1]

plt.figure(figsize=(10, 5))
sns.barplot(x=metrics, y=scores)
plt.ylim(0, 1)
plt.title('Precision, Recall, and F1 Score')
plt.ylabel('Score')
plt.show()
# Out:
# F1 Score: 0.9916284157765876

# %%
print(f"Precision: {precision_score}")
print(f"Recall: {recall_score}")
# Out:
# Precision: 0.9958071112632751
# Recall: 0.9989484548568726

# %%
print(f"F1 Score: {f1}")
# Out:
# F1 Score: 0.9916284157765876

# %%
print("Train Loss =", score)
print("Train Accuracy =", acc)
print("Test Loss =", score_v)
print("Test Accuracy =", acc_v)
# Out:
# Train Loss = 0.35178694128990173
# Train Accuracy = 0.9937291145324707
# Test Loss = 0.35941532254219055
# Test Accuracy = 0.991631805896759

# %%
## Calculate F1-score, Precision, Recall for Each Class
from sklearn.metrics import classification_report

# Assuming y_true and y_pred are already defined from previous cells
class_labels = ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']

# Generate classification report
report = classification_report(y_true, y_pred, target_names=class_labels, output_dict=True)

# Extract Precision, Recall, and F1 Score for each class
precision_per_class = {label: report[label]['precision'] for label in class_labels}
recall_per_class = {label: report[label]['recall'] for label in class_labels}
f1_per_class = {label: report[label]['f1-score'] for label in class_labels}

# Print the results
print("Precision per class:")
for label, score in precision_per_class.items():
    print(f"{label}: {score}")

print("\nRecall per class:")
for label, score in recall_per_class.items():
    print(f"{label}: {score}")

print("\nF1 Score per class:")
for label, score in f1_per_class.items():
    print(f"{label}: {score}")

# Plotting Precision, Recall, and F1 Score for each class
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.barplot(x=list(precision_per_class.keys()), y=list(precision_per_class.values()))
plt.ylim(0, 1)
plt.title('Precision per Class')
plt.ylabel('Precision')

plt.subplot(1, 3, 2)
sns.barplot(x=list(recall_per_class.keys()), y=list(recall_per_class.values()))
plt.ylim(0, 1)
plt.title('Recall per Class')
plt.ylabel('Recall')

plt.subplot(1, 3, 3)
sns.barplot(x=list(f1_per_class.keys()), y=list(f1_per_class.values()))
plt.ylim(0, 1)
plt.title('F1 Score per Class')
plt.ylabel('F1 Score')

plt.tight_layout()
plt.show()
# Out:
# Precision per class:
# Black spot: 0.995850622406639
# Canker: 0.9959016393442623
# Greening: 0.9806201550387597
# Healthy: 1.0
# Melanose: 0.9847715736040609
#
# Recall per class:
# Black spot: 0.9836065573770492
# Canker: 1.0
# Greening: 1.0
# Healthy: 0.9807692307692307
# Melanose: 0.9948717948717949
#
# F1 Score per class:
# Black spot: 0.9896907216494845
# Canker: 0.997946611909651
# Greening: 0.9902152641878669
# Healthy: 0.9902912621359222
# Melanose: 0.9897959183673469

# %%
## Confusion Matrix with Class Labels
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Assuming y_true and y_pred are already defined from previous cells
class_labels = ['Black spot', 'Canker', 'Greening', 'Healthy', 'Melanose']

# Generate confusion matrix
cm = confusion_matrix(y_true, y_pred)
cm_df = pd.DataFrame(cm, index=class_labels, columns=class_labels)

# Plotting the confusion matrix
plt.figure(figsize=(10, 7))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
## Save the Model
# Save the model
model_save_path = 'citrus_mbv3_model.h5'
citrus.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# Model saved to citrus_mbv3_model.h5

# %%
import os
import shutil

def get_model_size(model):
    model.save('temp_model')
    size = sum(os.path.getsize(os.path.join('temp_model', f)) for f in os.listdir('temp_model') if os.path.isfile(os.path.join('temp_model', f)))
    size_mb = size / (1024 * 1024)  # Đổi từ byte sang MB
    shutil.rmtree('temp_model')  # Xóa thư mục tạm thời sau khi tính toán
    return size_mb

model_size_mb = get_model_size(citrus)
print(f'Model size: {model_size_mb:.2f} MB')
# Out:
# Model size: 3.06 MB

# %%
import time
import numpy as np

def get_inference_time(model, input_shape=(224, 224, 3)):
    input_data = np.random.random([1] + list(input_shape)).astype(np.float32)
    start_time = time.time()
    _ = model.predict(input_data)
    end_time = time.time()
    inference_time_ms = (end_time - start_time) * 1000  # Đổi từ giây sang mili giây
    return inference_time_ms

inference_time_ms = get_inference_time(citrus)
print(f'Speed of single image recognition: {inference_time_ms:.2f} ms')
# Out:
# 1/1 [==============================] - 0s 46ms/step
# Speed of single image recognition: 101.76 ms
